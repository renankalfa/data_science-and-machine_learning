# %% [markdown]
# # Série temporal com Facebook Prophet
#
# - previsão de visualizações diárias de páginas web

# %% [markdown]
# ## Instalação da biblioteca e importação da base de dados
#
# - Visualizações diárias de uma página web da Wikipedia: https://en.wikipedia.org/wiki/Peyton_Manning

# %%
from fbprophet import Prophet
import pandas as pd

# %%
dataset = pd.read_csv('/content/page_wikipedia.csv')
dataset
# Out:
#             date      views
# 0     2007-12-10   9.590761
# 1     2007-12-11   8.519590
# 2     2007-12-12   8.183677
# 3     2007-12-13   8.072467
# 4     2007-12-14   7.893572
# ...          ...        ...
# 2900  2016-01-16   7.817223
# 2901  2016-01-17   9.273878
# 2902  2016-01-18  10.333775
# 2903  2016-01-19   9.125871
# 2904  2016-01-20   8.891374
#
# [2905 rows x 2 columns]

# %%
dataset.describe()
# Out:
#              views
# count  2905.000000
# mean      8.138958
# std       0.845957
# min       5.262690
# 25%       7.514800
# 50%       7.997999
# 75%       8.580168
# max      12.846747

# %%
dataset.hist();

# %% [markdown]
# Para trabalharmos com essa biblioteca precisamos renomear para o padrão aceito.

# %%
dataset = dataset[['date', 'views']].rename(columns = {'date': 'ds', 'views': 'y'})
dataset
# Out:
#               ds          y
# 0     2007-12-10   9.590761
# 1     2007-12-11   8.519590
# 2     2007-12-12   8.183677
# 3     2007-12-13   8.072467
# 4     2007-12-14   7.893572
# ...          ...        ...
# 2900  2016-01-16   7.817223
# 2901  2016-01-17   9.273878
# 2902  2016-01-18  10.333775
# 2903  2016-01-19   9.125871
# 2904  2016-01-20   8.891374
#
# [2905 rows x 2 columns]

# %% [markdown]
# Também é necessário que o dataset seja ordenado pelas datas.

# %%
dataset = dataset.sort_values(by = 'ds')
dataset
# Out:
#               ds          y
# 0     2007-12-10   9.590761
# 1     2007-12-11   8.519590
# 2     2007-12-12   8.183677
# 3     2007-12-13   8.072467
# 4     2007-12-14   7.893572
# ...          ...        ...
# 2900  2016-01-16   7.817223
# 2901  2016-01-17   9.273878
# 2902  2016-01-18  10.333775
# 2903  2016-01-19   9.125871
# 2904  2016-01-20   8.891374
#
# [2905 rows x 2 columns]

# %% [markdown]
# ## Construção do modelo e previsões

# %% [markdown]
# Carregando o modelo e o treinando.

# %%
model = Prophet()
model.fit(dataset)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# Passamos quantos dias queremos a previsão.

# %%
future = model.make_future_dataframe(periods=90)
forecast = model.predict(future)

# %% [markdown]
# Dentro da variável forecast teremos as previsões junto com o dataset original.

# %%
forecast.head()
# Out:
#           ds     trend  ...  multiplicative_terms_upper      yhat
# 0 2007-12-10  8.038509  ...                         0.0  8.841521
# 1 2007-12-11  8.036976  ...                         0.0  8.590090
# 2 2007-12-12  8.035443  ...                         0.0  8.385958
# 3 2007-12-13  8.033910  ...                         0.0  8.363878
# 4 2007-12-14  8.032377  ...                         0.0  8.351892
#
# [5 rows x 19 columns]

# %%
len(dataset), len(forecast)
# Out:
# (2905, 2995)

# %% [markdown]
# Os últimos 90 registros serão as previsões.

# %%
forecast.tail(90)
# Out:
#              ds     trend  ...  multiplicative_terms_upper      yhat
# 2905 2016-01-21  7.561398  ...                         0.0  8.561274
# 2906 2016-01-22  7.560382  ...                         0.0  8.577281
# 2907 2016-01-23  7.559367  ...                         0.0  8.345999
# 2908 2016-01-24  7.558351  ...                         0.0  8.714022
# 2909 2016-01-25  7.557335  ...                         0.0  9.022737
# ...         ...       ...  ...                         ...       ...
# 2990 2016-04-15  7.475050  ...                         0.0  6.914130
# 2991 2016-04-16  7.474034  ...                         0.0  6.701071
# 2992 2016-04-17  7.473018  ...                         0.0  7.089771
# 2993 2016-04-18  7.472002  ...                         0.0  7.421289
# 2994 2016-04-19  7.470986  ...                         0.0  7.214338
#
# [90 rows x 19 columns]

# %% [markdown]
# ## Gráfico das previsões

# %%
model.plot(forecast, xlabel = 'Date', ylabel = 'Views');

# %% [markdown]
# Podemos gerar três gráficos, um de cada componente.

# %%
model.plot_components(forecast);

# %%
from fbprophet.plot import plot_plotly, plot_components_plotly

# %%
plot_plotly(model, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_components_plotly(model, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
